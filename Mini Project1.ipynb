# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.isnull()
# Out:
#     city  humidity   temp
# 0  False     False  False
# 1  False     False  False
# 2  False     False   True
# 3  False     False  False
# 4  False     False  False
# 5  False      True  False
# 6  False     False  False

# %% [markdown]
# ### Exploring data

# %%
df.head()
# Out:
#   city  humidity  temp
# 0  Hyd      34.0  56.0
# 1  kkd      45.0  67.0
# 2  vzg      56.0   NaN
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0

# %%
df.tail()
# Out:
#         city  humidity  temp
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.head(3)
# Out:
#   city  humidity  temp
# 0  Hyd      34.0  56.0
# 1  kkd      45.0  67.0
# 2  vzg      56.0   NaN

# %%
df.tail(3)
# Out:
#         city  humidity  temp
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   city      7 non-null      object
#  1   humidity  6 non-null      float64
#  2   temp      6 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.describe()
# Out:
#         humidity       temp
# count   6.000000   6.000000
# mean   45.000000  63.000000
# std    19.677398  18.622567
# min    23.000000  32.000000
# 25%    34.000000  58.750000
# 50%    39.500000  67.000000
# 75%    53.250000  67.000000
# max    78.000000  89.000000

# %%
df.columns
# Out:
# Index(['city', 'humidity', 'temp'], dtype='object')

# %%
df.shape
# Out:
# (7, 3)

# %%
df['temp']=df['temp'].fillna(df['temp'].mean())
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df['humidity']=df['humidity'].fillna(df['humidity'].sum())
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.dtypes
# Out:
# city         object
# humidity    float64
# temp        float64
# dtype: object

# %%
df.city
# Out:
# 0          Hyd
# 1          kkd
# 2          vzg
# 3          Hyd
# 4          vzg
# 5          kkd
# 6    bangalore
# Name: city, dtype: object

# %%
df.humidity
# Out:
# 0     34.0
# 1     45.0
# 2     56.0
# 3     23.0
# 4     34.0
# 5    270.0
# 6     78.0
# Name: humidity, dtype: float64

# %%
df[['city','humidity']]
# Out:
#         city  humidity
# 0        Hyd      34.0
# 1        kkd      45.0
# 2        vzg      56.0
# 3        Hyd      23.0
# 4        vzg      34.0
# 5        kkd     270.0
# 6  bangalore      78.0

# %%
df[2:5]
# Out:
#   city  humidity  temp
# 2  vzg      56.0  63.0
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0

# %% [markdown]
# ### creating a database

# %%
data=({
    "Name":["Niha","Kavs","Vinay","Sri","Sai","Sagarika","Raju"],
    "Age": [12,23,45,67,23,23,12]
})
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.head()
# Out:
#   city  humidity  temp
# 0  Hyd      34.0  56.0
# 1  kkd      45.0  67.0
# 2  vzg      56.0  63.0
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0

# %%
df.tail()
# Out:
#         city  humidity  temp
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   city      7 non-null      object
#  1   humidity  7 non-null      float64
#  2   temp      7 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.describe()
# Out:
#          humidity  temp
# count    7.000000   7.0
# mean    77.142857  63.0
# std     86.918407  17.0
# min     23.000000  32.0
# 25%     34.000000  59.5
# 50%     45.000000  67.0
# 75%     67.000000  67.0
# max    270.000000  89.0

# %%
df.shape
# Out:
# (7, 3)

# %%
df.columns
# Out:
# Index(['city', 'humidity', 'temp'], dtype='object')

# %%
df.dtypes
# Out:
# city         object
# humidity    float64
# temp        float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.isnull()
# Out:
#     city  humidity   temp
# 0  False     False  False
# 1  False     False  False
# 2  False     False  False
# 3  False     False  False
# 4  False     False  False
# 5  False     False  False
# 6  False     False  False
