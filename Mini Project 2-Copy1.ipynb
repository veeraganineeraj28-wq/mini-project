# %%
import pandas as pd
df=pd.read_csv("dataset.csv")
df
# Out:
#    Study_Hours  Marks
# 0            0    2.9
# 1            1    5.8
# 2            2    4.7
# 3            3    4.0
# 4            4    1.8
# 5            5    1.8
# 6            6    1.3
# 7            7    5.3
# 8            8    4.0
# 9            9    4.5

# %%
df.min()
# Out:
# Study_Hours    0.0
# Marks          1.3
# dtype: float64

# %%
df.max()
# Out:
# Study_Hours    9.0
# Marks          5.8
# dtype: float64

# %%
df.columns
# Out:
# Index(['Study_Hours', 'Marks'], dtype='object')

# %%
df.head()
# Out:
#    Study_Hours  Marks
# 0            0    2.9
# 1            1    5.8
# 2            2    4.7
# 3            3    4.0
# 4            4    1.8

# %%
df.tail()
# Out:
#    Study_Hours  Marks
# 5            5    1.8
# 6            6    1.3
# 7            7    5.3
# 8            8    4.0
# 9            9    4.5

# %%
df['Marks'].mean()
# Out:
# np.float64(3.6099999999999994)

# %%
df['Marks'].mode()
# Out:
# 0    1.8
# 1    4.0
# Name: Marks, dtype: float64

# %%
df['Marks'].median()
# Out:
# 4.0

# %%
df['Marks'].std()
# Out:
# 1.5751190431202335

# %%
df['Marks'].var()
# Out:
# 2.481

# %%
df['Marks'].corr(df['Study_Hours'])
# Out:
# np.float64(-0.038443448034249726)
